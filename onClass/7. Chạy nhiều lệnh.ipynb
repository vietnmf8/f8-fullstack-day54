# %%
npm install --save-dev concurrently

# %%
{
    "scripts": {
        "dev-sever": "node --watch server.js",
        "queue": "node --watch queue.js",
        "schedule": "node --watch schedule.js",
		"dev": "concurrently 'npm run dev-server' 'npm run queue' 'npm run schedule'"
    }
    
}
